# %%
import argparse
import os
import shutil
import time

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models

import resnet
import vgg
import utils

# %%
vgg16 = vgg.vgg16()

# %%
vgg16.load_state_dict(torch.load('test_models/vgg16_pretrained.pth'))
# Out:
# <All keys matched successfully>

# %%
module_dict = utils.processNetwork(vgg16)
# Out:
# Creating dictionary...
# Cleaning up...

# %%
utils.plotNetwork(module_dict, 'vgg16', 512)
# Out:
# -1.2725645303726196
# 1.073387861251831

# %%
sns.palplot(sns.diverging_palette(240, 10, n=9, s=100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-aa5172c2b0c2> in <module>
# ----> 1 sns.palplot(sns.diverging_palette(240, 10, s=100, as_cmap=True))
#
# /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/seaborn/miscplot.py in palplot(pal, size)
#      18
#      19     """
# ---> 20     n = len(pal)
#      21     f, ax = plt.subplots(1, 1, figsize=(n * size, size))
#      22     ax.imshow(np.arange(n).reshape(1, n),
#
# TypeError: object of type 'LinearSegmentedColormap' has no len()
